# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch3/members.csv")

# 1) 결측치가 있는 행 제거 (기본값 axis=0)
df = df.dropna()
le = int(len(df)*.7)
print("결측치 제거 전:", int(len(df)))
print("결측치 제거 후:", le, "\n")

# 2) 앞에서부터 70% 데이터 슬라이싱
df = df.iloc[:le]

# 3) 1사분위 값 계산(정수 출력)
print(int(df['f1'].quantile(.25)))
# Out:
# 결측치 제거 전: 51
# 결측치 제거 후: 35
#
# 57

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch3/members.csv")

# 1) 결측치 수 컬럼별로 확인 및 변수에 대입(시리즈)
df_cntNull = df.isnull().sum()
print(df_cntNull, "\n")

# 방법 1: 2) 내림차순 정렬
df_cntNull = df_cntNull.sort_values(ascending=False)

# 방법 1: 3) 가장 상위에 있는 인덱스명 출력
print(df_cntNull.index[0])

# 방법 2: 2) 최대값 추출
df_max = df_cntNull.idxmax(axis=0)
print(df_max)
# Out:
# id             0
# age            0
# city           0
# f1            31
# f2             0
# f3            28
# f4             0
# f5             0
# subscribed     0
# views          4
# dtype: int64
#
# f1
# f1

# %%
import pandas as pd
# df = pd.read_csv("data4-1.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch4/data4-1.csv")

# 1) 3사분위수와 1사분위수의 차이를 절대값으로 계산
q1 = df['age'].quantile(0.25)
q3 = df['age'].quantile(0.75)
result = abs(q1 - q3)
print(df['age'], "\n")

# 2) 소수점 이하를 버리고, 정수로 출력
print(int(result))
# Out:
# 0       2.0
# 1       9.0
# 2      27.0
# 3      75.0
# 4      24.0
#       ...
# 95     92.0
# 96    100.0
# 97     39.0
# 98      1.0
# 99     47.0
# Name: age, Length: 100, dtype: float64
#
# 50

# %%
import pandas as pd
# df = pd.read_csv("data4-2.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch4/data4-2.csv")

# 1) 비율이 40%보다 크고 50%보다 작은 조건
cond = (df['loves'] + df['wows']) / df['reactions']
c1 = cond > .4
c2 = cond < .5

# 2) type이 video인 조건
c3 = df['type'] == 'video'

# 3) 조건에 맞는 데이터 수 구하기
print(len(df[c1 & c2 & c3]))
# Out:
# 90

# %%
import pandas as pd
# df = pd.read_csv("data5-2.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch5/data5-2.csv")

# 1) bmi 파생변수 계산
df['bmi'] = df['Weight'] / (df['Height']/100)**2

# 2) 조건1. 정상체중 bmi
cond1 = (df['bmi'] >= 18.5) & (df['bmi'] < 23)
print("정상체중인 사람 수:", len(df[cond1]))

# 3) 조건2. 위험체중 bmi
cond2 = (df['bmi'] >= 23) & (df['bmi'] < 25)
print("위험체중인 사람 수:", len(df[cond2]), "\n")

# 4) 조건1의 인원와 조건2의 인원 차이계산, 절대값 처리
print(abs(len(df[cond1]) - len(df[cond2])))
# Out:
# 정상체중인 사람 수: 1986
# 위험체중인 사람 수: 2130
#
# 144

# %%
import pandas as pd
# df = pd.read_csv("student_assessment.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch7/student_assessment.csv")

# 1) 결측치 제거
print("결측치 제거 전:", df.shape) # .shape 자료의 차원을 표현 ex) 가로*세로
df = df.dropna()
print("결측치 제거 후:", df.shape, "\n")

# 2) 가장 많이 수강한 과목 필터링
id = df['id_assessment'].value_counts().idxmax()
cond = df['id_assessment'] == id
df = df[cond]

# 3) 과목 점수 스탠다드 스케일
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() # 스탠다드 스케일: 값의 편차를 너무 크지 않도록 조정 평균: 0, 표준편차: 1
df['score'] = scaler.fit_transform(df[['score']])

# 4) 가장 큰 값
print(round(df['score'].max(), 3))
# Out:
# 결측치 제거 전: (2565, 4)
# 결측치 제거 후: (2544, 4)
#
# 2.183
